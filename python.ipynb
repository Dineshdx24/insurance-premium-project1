# %%
import pandas as pd
import os
df = pd.read_csv("train.csv")
df.head()
# Out:
#    id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   0  19.0  Female        10049.0        Married                   1.0
# 1   1  39.0  Female        31678.0       Divorced                   3.0
# 2   2  23.0    Male        25602.0       Divorced                   3.0
# 3   3  21.0    Male       141855.0        Married                   2.0
# 4   4  21.0    Male        39651.0         Single                   1.0
#
#   Education Level     Occupation  Health Score  Location  ... Previous Claims  \
# 0      Bachelor's  Self-Employed     22.598761     Urban  ...             2.0
# 1        Master's            NaN     15.569731     Rural  ...             1.0
# 2     High School  Self-Employed     47.177549  Suburban  ...             1.0
# 3      Bachelor's            NaN     10.938144     Rural  ...             1.0
# 4      Bachelor's  Self-Employed     20.376094     Rural  ...             0.0
#
# ...

# %%
df.set_index("id",inplace=True)

# %%
df.head()
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 0   19.0  Female        10049.0        Married                   1.0
# 1   39.0  Female        31678.0       Divorced                   3.0
# 2   23.0    Male        25602.0       Divorced                   3.0
# 3   21.0    Male       141855.0        Married                   2.0
# 4   21.0    Male        39651.0         Single                   1.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# id
# 0       Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1         Master's            NaN     15.569731     Rural  Comprehensive
# 2      High School  Self-Employed     47.177549  Suburban        Premium
# 3       Bachelor's            NaN     10.938144     Rural          Basic
# 4       Bachelor's  Self-Employed     20.376094     Rural        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Annual Income', 'Marital Status',
#        'Number of Dependents', 'Education Level', 'Occupation', 'Health Score',
#        'Location', 'Policy Type', 'Previous Claims', 'Vehicle Age',
#        'Credit Score', 'Insurance Duration', 'Policy Start Date',
#        'Customer Feedback', 'Smoking Status', 'Exercise Frequency',
#        'Property Type', 'Premium Amount'],
#       dtype='object')

# %%
df["Customer Feedback"].unique()
# Out:
# array(['Poor', 'Average', 'Good', nan], dtype=object)

# %%
df.isnull().sum()
# Out:
# Age                      18705
# Gender                       0
# Annual Income            44949
# Marital Status           18529
# Number of Dependents    109672
# Education Level              0
# Occupation              358075
# Health Score             74076
# Location                     0
# Policy Type                  0
# Previous Claims         364029
# Vehicle Age                  6
# Credit Score            137882
# Insurance Duration           1
# Policy Start Date            0
# Customer Feedback        77824
# Smoking Status               0
# Exercise Frequency           0
# Property Type                0
# Premium Amount               0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].median(),inplace=True)
# Out:
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_18344\860536840.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].median(),inplace=True)

# %%
df["Annual Income"].fillna(df["Annual Income"].median(),inplace=True)
# Out:
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_18344\2973224462.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Annual Income"].fillna(df["Annual Income"].median(),inplace=True)

# %%
df.fillna({"Marital Status": df["Marital Status"].mode()[0]},inplace=True)

# %%
df.fillna({"Number of Dependents": df["Number of Dependents"].median()},inplace=True)

# %%
import numpy as np

# %%
df["Occupation"]=df["Occupation"].fillna(np.random.choice(df["Occupation"].dropna()))

# %%
df.fillna({"Health Score": df["Health Score"].median()},inplace=True)

# %%
df.fillna({"Previous Claims": df["Previous Claims"].median()},inplace=True)

# %%
df.fillna({"Vehicle Age": df["Vehicle Age"].median()},inplace=True)

# %%
df.fillna({"Credit Score": df["Credit Score"].median()},inplace=True)

# %%
 df.fillna({"Insurance Duration": df["Insurance Duration"].median()},inplace=True)

# %%
df["Customer Feedback"]= df["Customer Feedback"].fillna(np.random.choice(df["Customer Feedback"].dropna()))

# %%
#df.columns

# %%
 df["Policy Start Date"] = pd.to_datetime(df["Policy Start Date"],format="%Y-%m-%d %H:%M:%S.%f")

# %%
df["Year"] = df["Policy Start Date"].dt.year
df["Month"] = df["Policy Start Date"].dt.month
df["Day"] = df["Policy Start Date"].dt.day
df["Week"] = df["Policy Start Date"].dt.isocalendar().week
df["Num_of_week"]=df["Policy Start Date"].dt.day_of_week
df["Hour"] = df["Policy Start Date"].dt.hour
df["Minute"] = df["Policy Start Date"].dt.minute

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",10)

# %%
df.head()
# Out:
#      Age  Gender  Annual Income Marital Status  Number of Dependents  \
# id
# 0   19.0  Female        10049.0        Married                   1.0
# 1   39.0  Female        31678.0       Divorced                   3.0
# 2   23.0    Male        25602.0       Divorced                   3.0
# 3   21.0    Male       141855.0        Married                   2.0
# 4   21.0    Male        39651.0         Single                   1.0
#
#    Education Level     Occupation  Health Score  Location    Policy Type  \
# id
# 0       Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1         Master's     Unemployed     15.569731     Rural  Comprehensive
# 2      High School  Self-Employed     47.177549  Suburban        Premium
# 3       Bachelor's     Unemployed     10.938144     Rural          Basic
# 4       Bachelor's  Self-Employed     20.376094     Rural        Premium
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# ...

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df.isnull().sum()
# Out:
# Age                     0
# Gender                  0
# Annual Income           0
# Marital Status          0
# Number of Dependents    0
#                        ..
# Day                     0
# Week                    0
# Num_of_week             0
# Hour                    0
# Minute                  0
# Length: 27, dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Gender"] = enc.fit_transform(df["Gender"])
df["Marital Status"] = enc.fit_transform(df["Marital Status"])
df["Education Level"] = enc.fit_transform(df["Education Level"])
df["Occupation"] = enc.fit_transform(df["Occupation"])
df["Location"] = enc.fit_transform(df["Location"])
df["Policy Type"] = enc.fit_transform(df["Policy Type"])
df["Customer Feedback"] = enc.fit_transform(df["Customer Feedback"])
df["Smoking Status"] = enc.fit_transform(df["Smoking Status"])
df["Exercise Frequency"] = enc.fit_transform(df["Exercise Frequency"])
df["Property Type"] = enc.fit_transform(df["Property Type"])

# %%
df.head()
# Out:
#      Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# id
# 0   19.0       0        10049.0               1                   1.0
# 1   39.0       0        31678.0               0                   3.0
# 2   23.0       1        25602.0               0                   3.0
# 3   21.0       1       141855.0               1                   2.0
# 4   21.0       1        39651.0               2                   1.0
#
#     Education Level  Occupation  Health Score  Location  Policy Type  \
# id
# 0                 0           1     22.598761         2            2
# 1                 2           2     15.569731         0            1
# 2                 1           1     47.177549         1            2
# 3                 0           2     10.938144         0            0
# 4                 0           1     20.376094         0            2
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# ...

# %%
#df.to_csv("Dx.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200000 entries, 0 to 1199999
# Data columns (total 27 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Age                   1200000 non-null  float64
#  1   Gender                1200000 non-null  int64
#  2   Annual Income         1200000 non-null  float64
#  3   Marital Status        1200000 non-null  int64
#  4   Number of Dependents  1200000 non-null  float64
#  5   Education Level       1200000 non-null  int64
#  6   Occupation            1200000 non-null  int64
#  7   Health Score          1200000 non-null  float64
#  8   Location              1200000 non-null  int64
#  9   Policy Type           1200000 non-null  int64
#  10  Previous Claims       1200000 non-null  float64
#  11  Vehicle Age           1200000 non-null  float64
#  12  Credit Score          1200000 non-null  float64
#  13  Insurance Duration    1200000 non-null  float64
# ...

# %%
#df

# %%
df.drop(["Policy Start Date"],axis=1,inplace=True)

# %%
pd.set_option("display.max_rows",None)

# %%
df.corr()
# Out:
#                            Age    Gender  Annual Income  Marital Status  \
# Age                   1.000000  0.000215       0.000061        0.000225
# Gender                0.000215  1.000000      -0.000983        0.001285
# Annual Income         0.000061 -0.000983       1.000000        0.004035
# Marital Status        0.000225  0.001285       0.004035        1.000000
# Number of Dependents  0.001399  0.000833       0.001920       -0.000658
# Education Level      -0.000416  0.000558       0.000257       -0.000986
# Occupation           -0.000108  0.001118      -0.001470        0.001402
# Health Score          0.000813  0.003412       0.023301        0.001610
# Location              0.001861  0.001225       0.000434        0.000519
# Policy Type          -0.000407 -0.001539      -0.000843        0.000155
# Previous Claims       0.001544 -0.000229       0.034777        0.000242
# Vehicle Age          -0.002436  0.000949      -0.000438        0.001132
# ...

# %%
df["Insurance Duration"].unique()
# Out:
# array([5., 2., 3., 1., 4., 6., 8., 9., 7.])

# %%
#df.columns

# %%
continues = ["Age","Annual Income","Health Score","Credit Score"]
categories =["Gender","Marital Status","Number of Dependents","Education Level","Occupation","Location","Policy Type","Previous Claims", 
             "Vehicle Age","Insurance Duration","Customer Feedback","Smoking Status","Exercise Frequency","Property Type"]

# %%
from scipy import stats

# %%
def two_sample(d1,d2):
    t=0
    f=0
    for i in range(31):
        sample1 = d1.sample(frac=0.03)
        sample2 = d2.sample(frac=0.03)
        t_test,p_value = stats.ttest_ind(sample1,sample2)
        if p_value < 0.05:
            f+=1
        else:
            t+=1
    if t>f:
        return True
    else:
        return False

# %%
def chisquare_test(d1,d2):
    return True if stats.chi2_contingency(pd.crosstab(d1,d2))[1]<0.05 else False

# %%
def annova_test(d1,d2):
  group=df[d2].unique()
  data={}
  for i in group:
    data[i]=df[d1][df[d2]==i]
  fvalue,p_value = stats.f_oneway(*[i for i in data.values()])
  return True if p_value<0.05 else False

# %%
final = {}
for i in df.columns:
    final[i] = {}
    for j in df.columns:
        if (i in continues) and (j in continues):
            result = two_sample(df[i],df[j])
        elif (i in categories) and (j in categories):
            result = chisquare_test(df[i],df[j])
        elif (i in continues) and (j in categories):
            result = annova_test(i,j)
        elif (i in categories) and (j in continues):
            result = annova_test(j,i)
        if result:
            final[i][j] = 1
        else:
            final[i][j] = 0

# %%
import pprint

# %%
final_df = pd.DataFrame(final)
final_df
# Out:
#                       Age  Gender  Annual Income  Marital Status  \
# Age                     1       0              0               0
# Gender                  0       1              0               1
# Annual Income           0       0              1               1
# Marital Status          0       1              1               1
# Number of Dependents    0       0              1               0
# Education Level         0       0              1               0
# Occupation              0       0              1               1
# Health Score            0       1              0               1
# Location                1       0              0               0
# Policy Type             0       0              0               0
# Previous Claims         1       0              1               0
# Vehicle Age             0       0              0               0
# Credit Score            0       0              0               1
# ...

# %%
#import seaborn as sns
#sns.heatmap(final_df,annot=True,cmap="coolwarm")

# %%
#print(continues,type(continues))

# %%
for i in continues:
  print(i,"Skew :",df[i].skew(),"Kurtosis",df[i].kurtosis())
# Out:
# Age Skew : -0.012124039077023422 Kurtosis -1.1663719030495063
# Annual Income Skew : 1.5229537478396937 Kurtosis 2.016891197172637
# Health Score Skew : 0.3073021274990332 Kurtosis -0.6348953667048627
# Credit Score Skew : -0.12578590724748864 Kurtosis -0.8414241913235956

# %%
for i in continues:
    if (df[i].skew() < 0.5 and df[i].skew() > -0.5) and (df[i].kurtosis() < 3 and df[i].kurtosis() > -3):
        continue
    print(i)
# Out:
# Annual Income

# %%
for i in continues:
    if (df[i].skew() < 0.5 and df[i].skew() > -0.5) and (df[i].kurtosis() < 3 and df[i].kurtosis() > -3):
        continue
    print(i)
    method = [1,-1,0,0.5,-0.5,2,-2]
    for j in method:
        print("Method",j,"Skew",pd.DataFrame(stats.boxcox(df[i],lmbda=j)).skew().values,"Kurtosis",pd.DataFrame(stats.boxcox(df[i],lmbda=j)).kurtosis().values)
# Out:
# Annual Income
# Method 1 Skew [1.52295375] Kurtosis [2.0168912]
# Method -1 Skew [-113.46016402] Kurtosis [30085.74576986]
# Method 0 Skew [-1.04955485] Kurtosis [1.45537946]
# Method 0.5 Skew [0.49718492] Kurtosis [-0.25847362]
# Method -0.5 Skew [-9.85489349] Kurtosis [202.19241183]
# Method 2 Skew [2.93478832] Kurtosis [8.94496845]
# Method -2 Skew [-663.46841922] Kurtosis [546617.58773856]

# %%
df["Annual Income"] = stats.boxcox(df["Annual Income"],lmbda=0.5)

# %%
df.head()
# Out:
#      Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# id
# 0   19.0       0     198.489401               1                   1.0
# 1   39.0       0     353.966291               0                   3.0
# 2   23.0       1     318.012500               0                   3.0
# 3   21.0       1     751.272859               1                   2.0
# 4   21.0       1     396.251177               2                   1.0
#
#     Education Level  Occupation  Health Score  Location  Policy Type  \
# id
# 0                 0           1     22.598761         2            2
# 1                 2           2     15.569731         0            1
# 2                 1           1     47.177549         1            2
# 3                 0           2     10.938144         0            0
# 4                 0           1     20.376094         0            2
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# ...

# %%
x = df.iloc[:,:-8]
x.head()
# Out:
#      Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# id
# 0   19.0       0     198.489401               1                   1.0
# 1   39.0       0     353.966291               0                   3.0
# 2   23.0       1     318.012500               0                   3.0
# 3   21.0       1     751.272859               1                   2.0
# 4   21.0       1     396.251177               2                   1.0
#
#     Education Level  Occupation  Health Score  Location  Policy Type  \
# id
# 0                 0           1     22.598761         2            2
# 1                 2           2     15.569731         0            1
# 2                 1           1     47.177549         1            2
# 3                 0           2     10.938144         0            0
# 4                 0           1     20.376094         0            2
#
#     Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# id
# ...

# %%
y = df["Premium Amount"]
y.head()
# Out:
# id
# 0    2869.0
# 1    1483.0
# 2     567.0
# 3     765.0
# 4    2022.0
# Name: Premium Amount, dtype: float64

# %%
#y.value_counts()

# %%
print(len(y.value_counts()))
# Out:
# 4794

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((960000, 18), (240000, 18), (960000,), (240000,))

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor().fit(x_train,y_train)

# %%
x_train.head()

# %%
y_train.head()

# %%
import numpy as np
dx = np.array([[45,1,404.536,1,1,2,2,42,1,1,1,6,650,8,0,1,2,1]])

# %%
model.predict(dx)
# Out:
# d:\vscode\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([1168.])

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#         id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  1200000  28.0  Female         2310.0            NaN                   4.0
# 1  1200001  31.0  Female       126031.0        Married                   2.0
# 2  1200002  47.0  Female        17092.0       Divorced                   0.0
# 3  1200003  28.0  Female        30424.0       Divorced                   3.0
# 4  1200004  24.0    Male        10863.0       Divorced                   2.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed      7.657981     Rural          Basic
# 1        Master's  Self-Employed     13.381379  Suburban        Premium
# 2             PhD     Unemployed     24.354527     Urban  Comprehensive
# 3             PhD  Self-Employed      5.136225  Suburban  Comprehensive
# 4     High School     Unemployed     11.844155  Suburban        Premium
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# ...

# %%
test.drop("Policy Start Date",axis=1,inplace=True)

# %%
test.columns
# Out:
# Index(['id', 'Age', 'Gender', 'Annual Income', 'Marital Status',
#        'Number of Dependents', 'Education Level', 'Occupation', 'Health Score',
#        'Location', 'Policy Type', 'Previous Claims', 'Vehicle Age',
#        'Credit Score', 'Insurance Duration', 'Customer Feedback',
#        'Smoking Status', 'Exercise Frequency', 'Property Type'],
#       dtype='object')

# %%
test.isnull().sum()

# %%
test["Property Type"].unique()
# Out:
# array(['House', 'Apartment', 'Condo'], dtype=object)

# %%
test.fillna({"Age": test["Age"].median()},inplace=True)

test.fillna({"Annual Income": test["Annual Income"].median()},inplace=True)

test.fillna({"Marital Status": test["Marital Status"].mode()[0]},inplace=True)

test.fillna({"Number of Dependents": test["Number of Dependents"].median()},inplace=True)

test["Occupation"]=test["Occupation"].fillna(np.random.choice(test["Occupation"].dropna()))

test.fillna({"Health Score": test["Health Score"].median()},inplace=True)

test.fillna({"Previous Claims": test["Previous Claims"].median()},inplace=True)

test.fillna({"Vehicle Age": test["Vehicle Age"].median()},inplace=True)

test.fillna({"Credit Score": test["Credit Score"].median()},inplace=True)

test.fillna({"Insurance Duration": test["Insurance Duration"].median()},inplace=True)

test["Customer Feedback"]= test["Customer Feedback"].fillna(np.random.choice(test["Customer Feedback"].dropna()))

# %%
test["Gender"] = enc.transform(test["Gender"])

# %%
test["Marital Status"] = enc.transform(test["Marital Status"])

# %%
test["Education Level"] = enc.transform(test["Education Level"])

# %%
test["Occupation"] = enc.transform(test["Occupation"])

# %%
test["Location"] = enc.transform(test["Location"])

# %%
test["Policy Type"] = enc.transform(test["Policy Type"])

# %%
test["Customer Feedback"] = enc.transform(test["Customer Feedback"])

# %%
test["Smoking Status"] = enc.transform(test["Smoking Status"])

# %%
test["Exercise Frequency"] = enc.transform(test["Exercise Frequency"])

# %%
test["Property Type"] = enc.transform(test["Property Type"])
